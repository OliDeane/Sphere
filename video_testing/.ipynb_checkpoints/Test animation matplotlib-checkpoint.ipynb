# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib
# matplotlib.use("Agg")
# %matplotlib notebook

# %%
def init_animation():
    global line
    line, = ax.plot(x, np.zeros_like(x))
    ax.set_xlim(0, 2*np.pi)
    ax.set_ylim(-1,1)

def animate(i):
    line.set_ydata(np.sin(2*np.pi*i / 50)*np.sin(x))
    return line



def init():
    ax.set_xlim(0, 2*np.pi)
    ax.set_ylim(-1, 1)
    return ln

def update(frame):
    xdata.append(frame)
    ydata.append(np.sin(frame))
    ln.set_data(xdata, ydata)
    return ln

# %%
# fig = plt.figure()
# ax = fig.add_subplot(111)
# x = np.linspace(0, 2*np.pi, 200)

fig, ax = plt.subplots()
xdata, ydata = [], []
ln, = plt.plot([], [], 'ro')

ani = animation.FuncAnimation(fig, update, frames=np.linspace(0, 2*np.pi, 128),
                    init_func=init, blit=True)
plt.show()
# ani.save('/tmp/animation.gif', writer='imagemagick', fps=30)

# mywriter = animation.FFMpegWriter(fps=60)
# ani.save('myanimation.mp4',writer=mywriter)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e2362d298c3d> in <module>
#       7 ln, = plt.plot([], [], 'ro')
#       8
# ----> 9 ani = animation.FuncAnimation(fig, update, frames=np.linspace(0, 2*np.pi, 128),
#      10                     init_func=init, blit=True)
#      11 plt.show()
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in __init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1654         self._save_seq = []
#    1655
# -> 1656         TimedAnimation.__init__(self, fig, **kwargs)
#    1657
#    1658         # Need to reset the saved seq, since right now it will contain data
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in __init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1413         if event_source is None:
#    1414             event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1415         Animation.__init__(self, fig, event_source=event_source,
#    1416                            *args, **kwargs)
#    1417
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in __init__(self, fig, event_source, blit)
#     943                                                       self._stop)
#     944         if self._blit:
# --> 945             self._setup_blit()
#     946
#     947     def _start(self, *args):
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _setup_blit(self)
#    1247         self._resize_id = self._fig.canvas.mpl_connect('resize_event',
#    1248                                                        self._on_resize)
# -> 1249         self._post_draw(None, self._blit)
#    1250
#    1251     def _on_resize(self, event):
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _post_draw(self, framedata, blit)
#    1200             self._blit_draw(self._drawn_artists)
#    1201         else:
# -> 1202             self._fig.canvas.draw_idle()
#    1203
#    1204     # The rest of the code in this class is to facilitate easy blitting
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2010         if not self._is_idle_drawing:
#    2011             with self._idle_draw_cntx():
# -> 2012                 self.draw(*args, **kwargs)
#    2013
#    2014     @cbook.deprecated("3.2")
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1868             self.stale = False
#    1869
# -> 1870         self.canvas.draw_event(renderer)
#    1871
#    1872     def draw_artist(self, a):
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in draw_event(self, renderer)
#    1757         s = 'draw_event'
#    1758         event = DrawEvent(s, self, renderer)
# -> 1759         self.callbacks.process(s, event)
#    1760
#    1761     def resize_event(self):
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     227                 except Exception as exc:
#     228                     if self.exception_handler is not None:
# --> 229                         self.exception_handler(exc)
#     230                     else:
#     231                         raise
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in _exception_printer(exc)
#      79 def _exception_printer(exc):
#      80     if _get_running_interactive_framework() in ["headless", None]:
# ---> 81         raise exc
#      82     else:
#      83         traceback.print_exc()
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     222             if func is not None:
#     223                 try:
# --> 224                     func(*args, **kwargs)
#     225                 # this does not capture KeyboardInterrupt, SystemExit,
#     226                 # and GeneratorExit
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _start(self, *args)
#     957
#     958         # Now do any initial draw
# --> 959         self._init_draw()
#     960
#     961         # Add our callback for stepping the animation and
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _init_draw(self)
#    1709                     raise RuntimeError('The init_func must return a '
#    1710                                        'sequence of Artist objects.')
# -> 1711                 for a in self._drawn_artists:
#    1712                     a.set_animated(self._blit)
#    1713         self._save_seq = []
#
# TypeError: 'Line2D' object is not iterable

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
# %matplotlib notebook
# plt.style.use('seaborn-pastel')


fig = plt.figure()
ax = plt.axes(xlim=(0, 4), ylim=(-2, 2))
line, = ax.plot([], [], lw=3)

def init():
    line.set_data([], [])
    return line,
def animate(i):
    x = np.linspace(0, 4, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)
plt.show()
# HTML(anim.to_html5_video())
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="698" height="522" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
mywriter = animation.FFMpegWriter(fps=60)
anim.save('myanimation.mp4',writer=mywriter)

# %%
def barlist(n): 
    return [1/float(n*k) for k in range(1,6)]

fig=plt.figure()

n=100 #Number of frames
x=range(1,6)
barcollection = plt.bar(x,barlist(1))

def animate(i):
    y=barlist(i+1)
    for i, b in enumerate(barcollection):
        b.set_height(y[i])

anim=FuncAnimation(fig,animate,repeat=False,blit=False,frames=n,
                             interval=100)
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %% [markdown]
# ## Custom Plot

# %%
fig = plt.figure()
# plt.plot([1,2,3],[1,2,3])
ax = plt.axes(xlim=(0, 4), ylim=(-2, 2))
line, = ax.plot([], [], lw=3)

# def init():
#     line.set_data([], [])
#     return line,


y_plot = np.zeros((100,1000))


for i in range(0,100):
    y_plot[i,:] = i*0.01
    
def init():
    line.set_data([], [])
    return line,

def animate(i):
    x = np.linspace(0, 4, 1000)
    y = y_plot[i,:]#np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="585.75">

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="698" height="522" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
fig = plt.figure()
ax = plt.axes(xlim=(0, 4), ylim=(-2, 2))
line, = ax.plot([], [], lw=3)

def init():
    line.set_data([], [])
    return line,
def animate(i):
    x = np.linspace(0, 4, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">
